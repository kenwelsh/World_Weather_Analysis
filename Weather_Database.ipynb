# %% [markdown]
# ### Import Dependencies

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time

# %% [markdown]
# ### Get 500+ Cities to Use for App

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination using citypy.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 633

# %% [markdown]
# ### Get Weather Data from OpenWeatherMap.org

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_main = city_weather["weather"][0]["main"]
        city_description = city_weather["weather"][0]["description"]
        
        # Set rain to 0.  Get 3h amount if available.  Use 1h amount if 3h not available.
        city_rain = 0
        if city_main == "Rain":
            try:
                city_rain = city_weather["rain"]["3h"]
            except:
                pass
        if city_main == "Rain" and city_rain == 0:
            try:
                city_rain = city_weather["rain"]["1h"]
            except:
                pass
        
        # Set snow to 0.  Get 3h amount if available. Use 1h amount if 3h not available.
        city_snow = 0
        if city_main == "Snow":
            try:
                city_snow = city_weather["snow"]["3h"]
            except:
                pass                          
        if city_main == "Snow" and city_snow == 0:
            try:
                city_snow = city_weather["snow"]["1h"]
            except:
                pass                          
            
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Weather": city_main,
                          "Weather Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Rain": city_rain,
                          "Snow": city_snow,
                          "Country": city_country,
                          "Date": city_date})
            
       
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zunheboto
# Processing Record 2 of Set 1 | innisfail
# Processing Record 3 of Set 1 | tuban
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | cidreira
# Processing Record 12 of Set 1 | lorengau
# Processing Record 13 of Set 1 | nara
# Processing Record 14 of Set 1 | toba
# Processing Record 15 of Set 1 | pevek
# Processing Record 16 of Set 1 | victoria
# Processing Record 17 of Set 1 | egvekinot
# Processing Record 18 of Set 1 | saskylakh
# Processing Record 19 of Set 1 | torbay
# Processing Record 20 of Set 1 | puerto escondido
# Processing Record 21 of Set 1 | jamestown
# ...

# %%
# checking number of cities added to city_data.
len(city_data)
# Out:
# 576

# %% [markdown]
# ### Create a Dataframe of the City Data

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng Weather Weather Description  Max Temp  \
# 0     Zunheboto  25.97   94.52    Rain          light rain     66.76
# 1     Innisfail -17.53  146.03    Rain       moderate rain     83.52
# 2         Tuban  -6.90  112.06    Rain          light rain     84.27
# 3     Cape Town -33.93   18.42   Clear           clear sky     64.99
# 4     Carnarvon -24.87  113.63   Clear           clear sky     82.40
# 5       Rikitea -23.12 -134.97  Clouds          few clouds     79.86
# 6   Port Alfred -33.59   26.89  Clouds          few clouds     62.01
# 7        Avarua -21.21 -159.78    Rain          light rain     84.20
# 8  Punta Arenas -53.15  -70.92  Clouds          few clouds     51.80
# 9   Tuktoyaktuk  69.45 -133.04    Snow          light snow      1.40
#
#    Humidity  Cloudiness  Wind Speed  Rain  Snow Country                 Date
# 0        57         100        0.47  0.31   0.0      IN  2020-02-23 03:09:50
# ...

# %%
# reorder columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Weather","Weather Description",
                    "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Rain", "Snow"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date    Lat     Lng Weather  \
# 0     Zunheboto      IN  2020-02-23 03:09:50  25.97   94.52    Rain
# 1     Innisfail      AU  2020-02-23 03:09:50 -17.53  146.03    Rain
# 2         Tuban      ID  2020-02-23 03:09:51  -6.90  112.06    Rain
# 3     Cape Town      ZA  2020-02-23 03:02:40 -33.93   18.42   Clear
# 4     Carnarvon      AU  2020-02-23 03:05:52 -24.87  113.63   Clear
# 5       Rikitea      PF  2020-02-23 03:05:35 -23.12 -134.97  Clouds
# 6   Port Alfred      ZA  2020-02-23 03:05:44 -33.59   26.89  Clouds
# 7        Avarua      CK  2020-02-23 03:04:29 -21.21 -159.78    Rain
# 8  Punta Arenas      CL  2020-02-23 03:01:08 -53.15  -70.92  Clouds
# 9   Tuktoyaktuk      CA  2020-02-23 03:00:57  69.45 -133.04    Snow
#
#   Weather Description  Max Temp  Humidity  Cloudiness  Wind Speed  Rain  Snow
# 0          light rain     66.76        57         100        0.47  0.31   0.0
# ...

# %%
city_data_df.count()
# Out:
# City                   576
# Country                576
# Date                   576
# Lat                    576
# Lng                    576
# Weather                576
# Weather Description    576
# Max Temp               576
# Humidity               576
# Cloudiness             576
# Wind Speed             576
# Rain                   576
# Snow                   576
# dtype: int64

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Calculate the cities that have recorded rain or snowfall.
# Not based on reported weather description but actual recorded rainfall or snowfall measurement.
city_rain_snow = city_data_df[(city_data_df["Rain"] > 0) | (city_data_df["Snow"] > 0)]
city_rain_snow_count = city_rain_snow["City"].count()
city_rain_snow_count
# Out:
# 92

# %% [markdown]
# ### 92 Cities *Recorded* Either Rainfall or Snowfall
